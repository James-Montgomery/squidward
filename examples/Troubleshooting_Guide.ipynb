# %%
import squidward.gpr as gpr

# %%
dir(gpr)
# Out:
# ['GaussianProcess',
#  'GaussianProcessStableCholesky',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'atleast_2d',
#  'check_valid_cov',
#  'invert',
#  'np']

# %%
help(gpr)
# Out:
# Help on module squidward.gpr in squidward:
#
# NAME
#     squidward.gpr
#
# DESCRIPTION
#     This script contains code for basic gaussian process regression. A regression
#     model can be created by calling one of these classes to create a model object.
#
# CLASSES
#     builtins.object
#         GaussianProcess
#         GaussianProcessStableCholesky
#
#     class GaussianProcess(builtins.object)
#      |  Model object for single output gaussian process (SOGP) regression.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, kernel=None, var_l=1e-15, inv_method='inv')
#      |      Description
#      |      ----------
#      |      Model object for single output gaussian process (SOGP) regression.
#      |
#      |      Parameters
#      |      ----------
#      |      kernel : kernel object
#      |          An object with an associated function k that takes in 2 arrays and
#      |          returns a valid K matrix. Valid K matricies are positive
# ...

# %%
gpr.__doc__
# Out:
# '\nThis script contains code for basic gaussian process regression. A regression\nmodel can be created by calling one of these classes to create a model object.\n'

# %%
gpr?

# %%
gpr??
