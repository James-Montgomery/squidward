# %%
import squidward.gpr as gpr
import squidward.kernels as kernels
import squidward.gp_viz as gp_viz
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Hierarchical 1D Regression

# %%
data_size = 1000

bids = auction = np.concatenate([
    np.linspace(0,50,data_size),
    np.linspace(0,50,data_size),
    np.linspace(0,50,data_size)
    ])

auction = np.concatenate([
    0.0*np.ones(data_size),
    1.0*np.ones(data_size),
    2.0*np.ones(data_size)
    ])

profit = np.ones(3*data_size)
profit[:data_size] = .7*bids[:data_size]+10*np.sin(.2*bids[:data_size])
profit[data_size:2*data_size] = .7*bids[data_size:2*data_size]+10*np.sin(.2*bids[data_size:2*data_size])-30
profit[-data_size:] = .7*bids[-data_size:]+10*np.sin(.2*bids[data_size:2*data_size])+50

# %%
sample_size = 15

indx = np.random.randint(0,3*data_size-1,sample_size)
bids_train = bids[indx]
auction_train = auction[indx]
profit_train = profit[indx] + np.random.normal(0,3,sample_size)

def one_hot(a, num_classes):
    a = a.astype(np.int32)
    return np.squeeze(np.eye(num_classes)[a.reshape(-1)])

auction_train_one_hot = one_hot(auction_train,3)
x = np.concatenate([bids_train.reshape(-1,1), auction_train.reshape(-1,1)], axis=1)
y = profit_train

# %%
plt.figure(figsize=(10,5))
plt.scatter(bids,profit,c=auction,s=1, cmap='autumn')
plt.scatter(bids_train,profit_train,c=auction_train,s=80,alpha=.7, cmap='autumn')
plt.show()

# %%
means, vars = [], []
kernel = kernels.rbf(100**2,15.0)
for i in range(3):
    ind = ((i == x)).nonzero()[0]
    y_ = y[ind]
    x_ = x[ind,0]
    model = gpr.gaussian_process(kernel=kernel,var_l=1**2,inv_method='solve')
    model.fit(x_,y_)
    x_test = np.linspace(0,50,100)
    mean, var = model.posterior_predict(x_test)
    means.append(mean)
    vars.append(vars)

# %%
plt.figure(figsize=(20,10))
gp_viz.regression.plot_1d(x_test,means[0],var[0])
gp_viz.regression.plot_1d(x_test,means[1],var[1])
gp_viz.regression.plot_1d(x_test,means[2],var[2])
plt.scatter(bids,profit,c=auction,s=1)
plt.scatter(bids_train,profit_train,c=auction_train,s=80,alpha=1.0)
plt.show()

# %%
x = np.concatenate([bids_train.reshape(-1,1), auction_train_one_hot], axis=1)

kernel = kernels.rbf3(10**2,10.0)
model = gpr.gaussian_process(kernel=kernel,var_l=5**2,inv_method='cholesky')
model.fit(x,y)

x_test = np.concatenate([bids.reshape(-1,1), one_hot(auction,3)], axis=1)
mean, var = model.posterior_predict(x_test)

# %%
plt.figure(figsize=(20,10))
gp_viz.regression.plot_1d(x_test[:data_size,0],mean[:data_size],var[:data_size,0])
gp_viz.regression.plot_1d(x_test[data_size:-data_size,0],mean[data_size:-data_size],var[data_size:-data_size,0])
gp_viz.regression.plot_1d(x_test[-data_size:,0],mean[-data_size:],var[-data_size:,0])
plt.scatter(bids,profit,c=auction,s=1, cmap='autumn')
plt.scatter(bids_train,profit_train,c=auction_train,s=80,alpha=.7, cmap='autumn')
plt.show()
